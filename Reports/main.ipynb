# %%
from random import randrange

import matplotlib.pyplot as plt
import numpy as np


size = int(1e6) 
counter = 0
for i in range(size):
    a = randrange(1, 8)
    b = randrange(1, 8)
    if (a-1)*7+ b-1<40:
        counter+=1
    
print(counter/size), print(40/49)
# Out:
# 0.816193
# 0.8163265306122449
# (None, None)

# %%
def rand7():
    return randrange(1, 8)

def rand10():
    while (n:=(rand7()-1)*7+ rand7()-1) >= 40:
        ...
    return (n%10)+1

# %%
res = []
for i in range(size):
    res.append(rand10())
    
# plot the histogram with corresponding number
plt.hist(res, bins=np.arange(1, 12)-0.5, rwidth=0.8, density=True)
# Out:
# (array([0.100535, 0.099998, 0.099891, 0.099956, 0.099701, 0.100278,
#         0.099817, 0.100108, 0.099725, 0.099991]),
#  array([ 0.5,  1.5,  2.5,  3.5,  4.5,  5.5,  6.5,  7.5,  8.5,  9.5, 10.5]),
#  <BarContainer object of 10 artists>)
