# %%
from random import randrange

import matplotlib.pyplot as plt
import numpy as np


size = int(1e6) 
counter = 0
for i in range(size):
    a = randrange(1, 8)
    b = randrange(1, 8)
    if (a-1)*7+ b-1<40:
        counter+=1
    
print(counter/size), print(40/49)
# Out:
# 0.815974
# 0.8163265306122449
# (None, None)

# %%
def rand7():
    return randrange(1, 8)

def rand10():
    while (n:=(rand7()-1)*7+ rand7()-1) >= 40:
        ...
    return (n%10)+1

# %%
res = []
for i in range(size):
    res.append(rand10())
    
# plot the histogram with corresponding number
plt.hist(res, bins=np.arange(1, 12)-0.5, rwidth=0.8, density=True)
# Out:
# (array([0.100312, 0.10055 , 0.099747, 0.099826, 0.099721, 0.099588,
#         0.100514, 0.099745, 0.099801, 0.100196]),
#  array([ 0.5,  1.5,  2.5,  3.5,  4.5,  5.5,  6.5,  7.5,  8.5,  9.5, 10.5]),
#  <BarContainer object of 10 artists>)

# %%
class Rand10:
    def __init__(self):
        self.cache = []
        self.compute_batch()
        
    def get(self):
        if not self.cache:
            self.compute_batch()
        return self.cache.pop()
        
    def compute_batch(self):
        while (s := sum([(rand7()-1)* (7**i) for i in range(19)])) > int(10**16):
            ...

        while True:
            self.cache.append(s % 10+1)
            if s < 9:
                break
            s = s // 10

r_generator = Rand10()
res = []
for i in range(size):
    res.append(r_generator.get())
    
# plot the histogram with corresponding number
plt.hist(res, bins=np.arange(1, 12)-0.5, rwidth=0.8, density=True)
# Out:
# (array([0.100181, 0.099901, 0.100113, 0.099663, 0.100195, 0.100291,
#         0.09986 , 0.099704, 0.099905, 0.100187]),
#  array([ 0.5,  1.5,  2.5,  3.5,  4.5,  5.5,  6.5,  7.5,  8.5,  9.5, 10.5]),
#  <BarContainer object of 10 artists>)

# %%
int(7**19)
# Out:
# 11398895185373143

# %%
i = 16
int(7**19), int(10**i), int(7**19)- int(10**i),  (int(7**19)- int(10**i)) / int(7**19)
# Out:
# (11398895185373143, 10000000000000000, 1398895185373143, 0.12272199740622057)
