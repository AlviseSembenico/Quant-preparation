# %%
from random import randrange

import matplotlib.pyplot as plt
import numpy as np


size = int(1e6) 
counter = 0
for i in range(size):
    a = randrange(1, 8)
    b = randrange(1, 8)
    if (a-1)*7+ b-1<40:
        counter+=1
    
print(counter/size), print(40/49)
# Out:
# 0.816678
# 0.8163265306122449
# (None, None)

# %%
def rand7():
    return randrange(1, 8)

def rand10():
    while (n:=(rand7()-1)*7+ rand7()-1) >= 40:
        ...
    return (n%10)+1

# %%
res = []
for i in range(size):
    res.append(rand10())
    
# plot the histogram with corresponding number
plt.hist(res, bins=np.arange(1, 12)-0.5, rwidth=0.8, density=True)
# Out:
# (array([0.100134, 0.100427, 0.099963, 0.099526, 0.100133, 0.100187,
#         0.100396, 0.099769, 0.099665, 0.0998  ]),
#  array([ 0.5,  1.5,  2.5,  3.5,  4.5,  5.5,  6.5,  7.5,  8.5,  9.5, 10.5]),
#  <BarContainer object of 10 artists>)

# %%
class Rand10:
    def __init__(self):
        self.cache = []
        self.compute_batch()
        
    def get(self):
        if not self.cache:
            self.compute_batch()
        return self.cache.pop()
        
    def compute_batch(self):
        s = sum([(rand7()-1)* (7**i) for i in range(19)])

        while s > 0:
            self.cache.append(s % 10)
            s = s // 10

r_generator = Rand10()
res = []
for i in range(size):
    res.append(r_generator.get())
    
# plot the histogram with corresponding number
plt.hist(res, bins=np.arange(1, 12)-0.5, rwidth=0.8, density=True)
# Out:
# (array([0.12081806, 0.11071271, 0.11023774, 0.10969397, 0.11035537,
#         0.11015784, 0.10968287, 0.10925229, 0.10908915, 0.        ]),
#  array([ 0.5,  1.5,  2.5,  3.5,  4.5,  5.5,  6.5,  7.5,  8.5,  9.5, 10.5]),
#  <BarContainer object of 10 artists>)
